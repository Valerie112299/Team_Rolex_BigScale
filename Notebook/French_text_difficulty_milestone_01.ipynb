# %% [markdown]
# <a href="https://colab.research.google.com/github/Valerie112299/Team_Rolex_BigScale/blob/main/French_text_difficulty_milestone_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LingoRand
# Or how to become a millionaire.
#
# *Let's build a model for English speakers that predicts the difficulty of a French written text.*
#
# Lirette Teiffouet, Valerie Tsague

# %% [markdown]
# * [Click here ](https://github.com/Rolex-Github/Team_Rolex_BigScale) to open our githup repo
# * Callable API point which, given a text in French, will return its difficulty : [here](https://console.cloud.google.com/natural-language/locations/eu/datasets/TCN4260858246283132928;modelId=TCN6916178827362172928/predict?project=rising-dominion-348717)
#  we had some troubles with this .............

# %% [markdown]
# # 1- Results optain from google autoML

# %% [markdown]
# a. What is the
# * accuracy  : 0,503
# * various metrics :
#   * precision : 0,58
#   * recall:0,32

# %% [markdown]
# b. Do you understand what they mean?
# *  Regarding the confusion metrics down below given by automl train, we can notice that A1 class has the best score (about 66%) which means that 66% of of predictions for that class is correct. This is not the case for b2 class with about 39% of good precision

# %% [markdown]
# c. Techniques to improve our scores:
# * Add more data of class 2 B2 data into our dataset
# *  Maybe remove / correct  some data of class B2 in order to make sure that there is no error
# * train after each change

# %% [markdown]
#  Precision,

# %% [markdown]
# ![Capture1.PNG](data:image/png;base64,...)

# %% [markdown]
# #2. Confusion metrics

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)
